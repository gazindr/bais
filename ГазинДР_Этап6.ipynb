# %% [markdown]
# # Газин ДР, Этап 6

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
reg = linear_model.LinearRegression()
np.random.seed(19130339)
A = []
B = []
T = []
N = 10000
n = 1000

# %%
for i in range(n):
  t = time.time()
  x = np.random.uniform(low=150, high=200, size=N)
  e  = np.random.normal(loc=0, scale=10, size=N)
  y = -100 + x + e
  reg.fit(x.reshape(-1,1), y.reshape (-1, 1))
  A.append (reg.intercept_[0])
  B.append(reg.coef_[0][0])
  T.append(time.time() - t)

# %%
plt.figure(figsize=(10,6))
plt.hist(B, bins = 20, edgecolor = 'black', color='white')
plt.title('Histogram of B estimates')
plt.show()

# %%
min(T), np.median(T), max(T)
# Out:
# (0.0010743141174316406, 0.0011115074157714844, 0.02454853057861328)

# %%
plt.figure(figsize=(10,4))
plt.plot(T, marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T[410:500], marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.hist(T[410:450], bins=30,edgecolor='black', color = 'white')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T, marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T[365:560], marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.hist(T[375:400], bins=30,edgecolor='black', color = 'white')
plt.show()
